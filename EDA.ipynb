# %%
import pandas as pd

# %%
data = pd.read_csv('data/winemag-data-130k-v2.csv', index_col = 0)

# %%
len(data)
# Out:
# 129971

# %%
data
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country                129908 non-null  object
#  1   description            129971 non-null  object
#  2   designation            92506 non-null   object
#  3   points                 129971 non-null  int64
#  4   price                  120975 non-null  float64
#  5   province               129908 non-null  object
#  6   region_1               108724 non-null  object
#  7   region_2               50511 non-null   object
#  8   taster_name            103727 non-null  object
#  9   taster_twitter_handle  98758 non-null   object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 13.9+ MB

# %%
data.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# ### Column Description
# country - of wine
# description - to work on
# designation - vineyard of winery
# points - review/100
# price - of wine (has nulls)
# province, region_1, region_2 - locality of wine growing area (has nulls)
# taster_name, taster_twitter_handle - person who reviewed (drop)
# winery - of wine
# variety - type of grape used
# title - of wine
# ### ------------------------

# %% [markdown]
# Number of null values :

# %%
data.isna().sum()
# Out:
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Number of reviews by country

# %%
plt.figure(figsize=(20,5))
sns.set(style='darkgrid')
sns.barplot(x=data.country.value_counts()[:10].index,
            y=data.country.value_counts()[:10].values)
plt.xlabel('Countries')
plt.ylabel('Number of reviews')
plt.show()

# %% [markdown]
# ### Top Average Rating

# %%
plt.figure(figsize=(16,7))
g = sns.barplot(x=data.groupby("country").mean().sort_values(by="points",ascending=False).points.index[:10], y=data.groupby("country").mean().sort_values(by="points",ascending=False).points.values[:10], palette="gist_ncar")
plt.xlabel("Countries")
plt.ylabel("Average Rating")
ax=g
for p in ax.patches:
    ax.annotate("%.2f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=11, color='gray', xytext=(0, 20),
                 textcoords='offset points')
plt.show()

# %% [markdown]
# India rank 2 damn
# ### Top Average Price

# %%
plt.figure(figsize=(16,7))
g = sns.barplot(x=data.groupby("country").mean().sort_values(by="price",ascending=False).price.index[:10], y=data.groupby("country").mean().sort_values(by="price",ascending=False).price.values[:10], palette="Blues_r")
plt.xlabel("Countries")
plt.ylabel("Average Price (US Dollar)")
ax=g
for p in ax.patches:
    ax.annotate("%.2f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=11, color='gray', xytext=(0, 20),
                 textcoords='offset points')
plt.show()

# %% [markdown]
# Supressing Warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Points to Price Ratio

# %%
data2 = data[np.isfinite(data["price"])]
data2["points/price"] = data2.points / data2.price
data2.groupby("country").mean().sort_values(by="points/price", ascending=False)
plt.figure(figsize=(16,7))
g = sns.barplot(x=data2.groupby("country").mean().sort_values(by="points/price", ascending=False)["points/price"].index[:10], y=data2.groupby("country").mean().sort_values(by="points/price", ascending=False)["points/price"].values[:10], palette="jet_r")
plt.xlabel("Countries")
plt.xticks(rotation= 45, ha="right")
plt.ylabel("Points / Price Ratio")
ax=g
for p in ax.patches:
    ax.annotate("%.2f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=11, color='gray', xytext=(0, 20),
                 textcoords='offset points')
plt.show()

# %% [markdown]
# ### Points Boxplot

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x=data.points)
plt.show()

# %% [markdown]
# Therefore no reviews below ~85 have been taken (all positive, tough to use)

# %% [markdown]
# ### Best Wines According to Points

# %%
top20Points = data.sort_values(by="points", ascending=False).head(20)
for i in range(20):
    print("{} / {} / {} / $ {} / Points - {}".format(top20Points.title.values[i], top20Points.country.values[i], top20Points.province.values[i], top20Points.price.values[i], top20Points.points.values[i]))
    print("-----------------------------------------------------------------------------------------------------------------------")
# Out:
# Quinta do Noval 2011 Nacional Vintage  (Port) / Portugal / Port / $ 650.0 / Points - 100
# -----------------------------------------------------------------------------------------------------------------------
# Salon 2006 Le Mesnil Blanc de Blancs Brut Chardonnay (Champagne) / France / Champagne / $ 617.0 / Points - 100
# -----------------------------------------------------------------------------------------------------------------------
# Charles Smith 2006 Royal City Syrah (Columbia Valley (WA)) / US / Washington / $ 80.0 / Points - 100
# -----------------------------------------------------------------------------------------------------------------------
# Biondi Santi 2010 Riserva  (Brunello di Montalcino) / Italy / Tuscany / $ 550.0 / Points - 100
# -----------------------------------------------------------------------------------------------------------------------
# Cayuse 2008 Bionic Frog Syrah (Walla Walla Valley (WA)) / US / Washington / $ 80.0 / Points - 100
# ...

# %% [markdown]
# ### Producer of top 20 wines by country

# %%
labels = top20Points.country.value_counts().index
values = top20Points.country.value_counts().values
plt.figure(figsize=(12,6))
plt.pie(values, labels = labels)
plt.plot()
# Out:
# []

# %% [markdown]
# ### Top 10 grapes used to make wine

# %%
plt.figure(figsize=(12,6))
plt.pie(data.variety.value_counts().values[:10], labels = data.variety.value_counts().index[:10])
plt.plot()
# Out:
# []

# %% [markdown]
# Both Pie graphs go anticlockwise in descending order starting from positive X
